# %%
import csv
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)

# %%
sns.countplot(train['YrSold'])

# %%
f, ax = plt.subplots(figsize=(15,12))
train_corr = train.corr()['SalePrice'].sort_values()
train_corr.plot.bar()
plt.show()
train_corr
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# YrSold          -0.028923
# LowQualFinSF    -0.025606
# MiscVal         -0.021190
# BsmtHalfBath    -0.016844
# BsmtFinSF2      -0.011378
# 3SsnPorch        0.044584
# MoSold           0.046432
# PoolArea         0.092404
# ScreenPorch      0.111447
# BedroomAbvGr     0.168213
# BsmtUnfSF        0.214479
# BsmtFullBath     0.227122
# LotArea          0.263843
# HalfBath         0.284108
# OpenPorchSF      0.315856
# 2ndFlrSF         0.319334
# WoodDeckSF       0.324413
# LotFrontage      0.351799
# BsmtFinSF1       0.386420
# Fireplaces       0.466929
# MasVnrArea       0.477493
# GarageYrBlt      0.486362
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# TotRmsAbvGrd     0.533723
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# GrLivArea        0.708624
# OverallQual      0.790982
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
attribute_of_interest = train_corr[-15:].index
train_subset = train[attribute_of_interest]
list(attribute_of_interest)
# Out:
# ['BsmtFinSF1',
#  'Fireplaces',
#  'MasVnrArea',
#  'GarageYrBlt',
#  'YearRemodAdd',
#  'YearBuilt',
#  'TotRmsAbvGrd',
#  'FullBath',
#  '1stFlrSF',
#  'TotalBsmtSF',
#  'GarageArea',
#  'GarageCars',
#  'GrLivArea',
#  'OverallQual',
#  'SalePrice']

# %%
f, ax = plt.subplots(figsize=(15,12))
sns.heatmap(train_subset.corr(), vmax=.8, square=True, annot=True)

# %%
remove_features = ['TotalBsmtSF', 'GarageCars', 'GarageYrBlt']
train_subset = train_subset.drop(remove_features, axis=1)
attribute_of_interest = [feature for feature in attribute_of_interest if feature not in remove_features]

# %%
fig, axs = plt.subplots(ncols=1, nrows=len(attribute_of_interest)-1, figsize=(10, 100))
for i,index in enumerate(attribute_of_interest):
    if index!='SalePrice':
        if index == 'OverallQual':
            plt.xlim(0, 12)
        sns.regplot(train_subset[index], train_subset['SalePrice'], fit_reg=False,ax=axs[i])

# %%
train_subset = train_subset.dropna()
train_subset = train_subset[train_subset['SalePrice']>60000]
train_subset = train_subset[train_subset['BsmtFinSF1']<2000]
train_subset = train_subset[train_subset['TotRmsAbvGrd']<13]
